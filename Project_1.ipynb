# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', lambda x: f"{x:,.2f}")

sns.set(style='whitegrid')

# %% [markdown]
# ### Exercises – Section 1
# 1. Add another pandas display option to set the display width (hint: `display.width`).
# 2. Change the seaborn style from `'whitegrid'` to `'darkgrid'` and re-run a plot later.

# %% [markdown]
# ## 2. Load the Stroke Dataset
#
# In Colab, we typically upload a CSV file from our local machine and then read it with `pandas.read_csv()`.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")
df.head()
df.sample(10)
# Out:
#        School DBN                                        School Name  \
# 29001      08X561                          Bronx Compass High School
# 187458     22K405                                Midwood High School
# 182710     19K507         Performing Arts and Technology High School
# 187691     22K425                          James Madison High School
# 6931       10X504                                       Kennedy Yabc
# 153993     06M211  Inwood Early College for Health and Informatio...
# 10306      17K352                         Ebbets Field Middle School
# 4666       08X305                               Pablo Neruda Academy
# 98928      84K473                   Williamsburg Charter High School
# 130419     26Q415                    Benjamin N. Cardozo High School
#
#                            School Level                 Regents Exam  Year  \
# 29001                       High school  U.S. History and Government  2015
# 187458                      High school         Common Core Algebra2  2016
# 182710                      High school                     Geometry  2015
# 187691                      High school                     Geometry  2015
# 6931                        High school         Common Core Geometry  2016
# 153993                      High school         Common Core Geometry  2016
# 10306   Junior High-Intermediate-Middle          Common Core Algebra  2017
# 4666                        High school         Common Core Geometry  2017
# 98928                       High school         Common Core Geometry  2015
# 130419                      High school        Algebra2/Trigonometry  2015
#
#         Total Tested Mean Score Number Scoring Below 65  \
# 29001             84         61                      48
# 187458             9       69.2                       2
# 182710             2          s                       s
# 187691             5          s                       s
# 6931               1          s                       s
# 153993             2          s                       s
# 10306             15       74.4                       2
# 4666              59       49.4                      53
# 98928             90       53.5                      78
# 130419           310       69.1                     121
#
#        Percent Scoring Below 65 Number Scoring 65 or Above  \
# 29001                      57.1                         36
# 187458                     22.2                          7
# 182710                        s                          s
# 187691                        s                          s
# 6931                          s                          s
# 153993                        s                          s
# 10306                      13.3                         13
# 4666                       89.8                          6
# 98928                      86.7                         12
# 130419                       39                        189
#
#        Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 29001                         42.9                          9
# 187458                        77.8                          0
# 182710                           s                          s
# 187691                           s                          s
# 6931                             s                          s
# 153993                           s                          s
# 10306                         86.7                          2
# 4666                          10.2                          2
# 98928                         13.3                          0
# 130419                          61                         98
#
#        Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 29001                         10.7                na                 na
# 187458                           0                 7               77.8
# 182710                           s                na                 na
# 187691                           s                na                 na
# 6931                             s                na                 na
# 153993                           s                na                 na
# 10306                         13.3                13               86.7
# 4666                           3.4                 3                5.1
# 98928                            0                 6                6.7
# 130419                        31.6                98               31.6

# %% [markdown]
# ### Exercises – Section 2
# 1. Show the first 10 rows instead of 5 using `df.head(10)`.
# 2. Use `df.sample(5)` to view 5 random rows. Why might this be useful?
# 3. Intentionally change `file_name` to something incorrect and run the cell. What error do you see?

# %% [markdown]
# ## 3. First Look at the Data
#
# We now inspect the basic structure of the dataset:
# - Number of rows and columns (`df.shape`)
# - Column names (`df.columns`)
# - Data types and non-null counts (`df.info()`)
# - Summary statistics for numeric columns (`df.describe()`).

# %%
print('Shape (rows, columns):', df.shape)

print('\nColumn names:')
print(df.columns)

print('\nData types and non-null counts:')
df.info()

print('\nSummary statistics (numeric columns):')
df.describe()
# Out:
# Shape (rows, columns): (212331, 15)
#
# Column names:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
#  12  Percent Scoring 80 or Above  212331 non-null  object
#  13  Number Scoring CR            212331 non-null  object
#  14  Percent Scoring CR           212331 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 24.3+ MB
#
# Summary statistics (numeric columns):
#             Year  Total Tested
# count 212,331.00    212,331.00
# mean    2,015.96         49.36
# std         0.80         93.02
# min     2,015.00          1.00
# 25%     2,015.00          5.00
# 50%     2,016.00         20.00
# 75%     2,017.00         57.00
# max     2,017.00      1,729.00

# %% [markdown]
# ### Exercises – Section 3
# 1. How many rows and columns does the dataset have?
# 2. From `df.info()`, list which columns are numeric and which are `object` (string-like).
# 3. Run `df.describe(include='all')` in a new cell. What extra information do you get?

# %% [markdown]
# ## 4. Inspect Raw Data & Categorical Columns
#
# Before cleaning, it's helpful to look at actual values to spot issues such as strange strings or inconsistent categories.

# %%
# First 10 rows
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
# 5   Living Environment  2015             9       67.4                       3
# 6   Living Environment  2016            15       72.6                       2
# 7   Living Environment  2017             9       64.4                       5
# 8  Common Core Algebra  2015            49       78.4                       1
# 9  Common Core Algebra  2016            51         79                       9
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# 1                      6.3                         15
# 2                     11.1                          8
# 3                        s                          s
# 4                        s                          s
# 5                     33.3                          6
# 6                     13.3                         13
# 7                     55.6                          4
# 8                        2                         48
# 9                     17.6                         42
#
#   Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 0                           s                          s
# 1                        93.8                          7
# 2                        88.9                          2
# 3                           s                          s
# 4                           s                          s
# 5                        66.7                          0
# 6                        86.7                          5
# 7                        44.4                          1
# 8                          98                         23
# 9                        82.4                         33
#
#   Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 0                           s                na                 na
# 1                        43.8                na                 na
# 2                        22.2                na                 na
# 3                           s                na                 na
# 4                           s                na                 na
# 5                           0                na                 na
# 6                        33.3                na                 na
# 7                        11.1                na                 na
# 8                        46.9                48                 98
# 9                        64.7                40               78.4

# %%
# Random sample of 5 rows
df.sample(5, random_state=42)
# Out:
#        School DBN                              School Name      School Level  \
# 198472     28Q350          Jamaica Gateway to the Sciences       High school
# 100707     84M353       New Heights Academy Charter School  Secondary School
# 117361     11X509   High School of Language and Innovation       High school
# 42854      22K555                 Brooklyn College Academy       High school
# 179934     17K590  Medgar Evers College Preparatory School  Secondary School
#
#                            Regents Exam  Year  Total Tested Mean Score  \
# 198472  Physical Settings/Earth Science  2015            45       70.6
# 100707                         Geometry  2015            61       54.2
# 117361               Living Environment  2016           101       58.9
# 42854                Living Environment  2015            18       56.7
# 179934      Physical Settings/Chemistry  2015             3          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 198472                      11                     24.4
# 100707                      45                     73.8
# 117361                      64                     63.4
# 42854                       15                     83.3
# 179934                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 198472                         34                        75.6
# 100707                         16                        26.2
# 117361                         37                        36.6
# 42854                           3                        16.7
# 179934                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 198472                         11                        24.4
# 100707                          5                         8.2
# 117361                          2                           2
# 42854                           1                         5.6
# 179934                          s                           s
#
#        Number Scoring CR Percent Scoring CR
# 198472                na                 na
# 100707                 5                8.2
# 117361                na                 na
# 42854                 na                 na
# 179934                na                 na

# %%
# Summary statistics for all columns (numeric + non-numeric)
df.describe(include='all')
# Out:
#        School DBN                                        School Name  \
# count      212331                                             212331
# unique       1018                                               1012
# top        26Q430  New Visions Charter High School for Advanced Math
# freq          490                                               1337
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        School Level         Regents Exam       Year  Total Tested Mean Score  \
# count        212331               212321 212,331.00    212,331.00     212331
# unique            6                   14        NaN           NaN        748
# top     High school  Common Core Algebra        NaN           NaN          s
# freq         151160                29254        NaN           NaN      75222
# mean            NaN                  NaN   2,015.96         49.36        NaN
# std             NaN                  NaN       0.80         93.02        NaN
# min             NaN                  NaN   2,015.00          1.00        NaN
# 25%             NaN                  NaN   2,015.00          5.00        NaN
# 50%             NaN                  NaN   2,016.00         20.00        NaN
# 75%             NaN                  NaN   2,017.00         57.00        NaN
# max             NaN                  NaN   2,017.00      1,729.00        NaN
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# count                   212331                   212331
# unique                     446                      992
# top                          s                        s
# freq                     75222                    75222
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# count                      212331                      212331
# unique                        945                         992
# top                             s                           s
# freq                        75222                       75222
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# count                      212331                      212331
# unique                        744                        1000
# top                             s                           s
# freq                        75222                       75222
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
#
#        Number Scoring CR Percent Scoring CR
# count             212331             212331
# unique               707                999
# top                   na                 na
# freq              142680             142680
# mean                 NaN                NaN
# std                  NaN                NaN
# min                  NaN                NaN
# 25%                  NaN                NaN
# 50%                  NaN                NaN
# 75%                  NaN                NaN
# max                  NaN                NaN

# %% [markdown]
# ### Exercises – Section 4
# 1. Use `df.tail(8)` to view the last 8 rows. Do they look similar to the first rows?
# 2. Check unique values of `gender` using `df['gender'].unique()`.
# 3. Check the frequency of `work_type` using `df['work_type'].value_counts()`.

# %% [markdown]
# ## 5. Missing Values & Unique Values
#
# We want to know where data is missing and how many unique values each column has.

# %%
print('Missing values per column:')
print(df.isna().sum())

print('\nPercentage of missing values per column:')
print((df.isna().mean() * 100).round(2))

print('\nNumber of unique values per column:')
print(df.nunique())
# Out:
# Missing values per column:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64
#
# Percentage of missing values per column:
# School DBN                    0.00
# School Name                   0.00
# School Level                  0.00
# Regents Exam                  0.00
# Year                          0.00
# Total Tested                  0.00
# Mean Score                    0.00
# Number Scoring Below 65       0.00
# Percent Scoring Below 65      0.00
# Number Scoring 65 or Above    0.00
# Percent Scoring 65 or Above   0.00
# Number Scoring 80 or Above    0.00
# Percent Scoring 80 or Above   0.00
# Number Scoring CR             0.00
# Percent Scoring CR            0.00
# dtype: float64
#
# Number of unique values per column:
# School DBN                     1018
# School Name                    1012
# School Level                      6
# Regents Exam                     14
# Year                              3
# Total Tested                   1126
# Mean Score                      748
# Number Scoring Below 65         446
# Percent Scoring Below 65        992
# Number Scoring 65 or Above      945
# Percent Scoring 65 or Above     992
# Number Scoring 80 or Above      744
# Percent Scoring 80 or Above    1000
# Number Scoring CR               707
# Percent Scoring CR              999
# dtype: int64

# %% [markdown]
# ### Exercises – Section 5
# 1. Which column has the highest percentage of missing values?
# 2. Approximately what percentage of `bmi` values are missing?
# 3. How many unique categories does `smoking_status` have?

# %% [markdown]
# ## 6. Basic Data Cleaning
#
# We will:
# 1. Clean column names (lowercase, replace spaces with underscores)
# 2. Fix special missing values in `bmi` (e.g., 'N/A')
# 3. Convert `bmi` and `avg_glucose_level` to numeric types.

# %%
# 1. Clean column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_')
      .str.replace('-', '_')
)
df.columns
# Out:
# Index(['school_dbn', 'school_name', 'school_level', 'regents_exam', 'year',
#        'total_tested', 'mean_score', 'number_scoring_below_65',
#        'percent_scoring_below_65', 'number_scoring_65_or_above',
#        'percent_scoring_65_or_above', 'number_scoring_80_or_above',
#        'percent_scoring_80_or_above', 'number_scoring_cr',
#        'percent_scoring_cr'],
#       dtype='object')

# %%
# Inspect unique values in bmi
df['school_name'].unique()[:20]
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', 'P.S. 188 The Island School',
#        'Orchard Collegiate Academy',
#        'Technology, Arts, and Sciences Studio',
#        'University Neighborhood Middle School',
#        'Collaborative Academy of Science, Technology, & La',
#        'School for Global Leaders', 'University Neighborhood High School',
#        'East Side Community School', 'Forsyth Satellite Academy',
#        'Marta Valle High School',
#        'Lower East Side Preparatory High School',
#        'New Explorations into Science, Technology and Math',
#        'Cascades High School', 'Bard High School Early College',
#        'Tompkins Square Middle School',
#        '47 The American Sign Language and English Secondar',
#        'J.H.S. 104 Simon Baruch'], dtype=object)

# %%
# Replace 'N/A' with actual NaN and convert to numeric
df['school_name'] = df['school_name'].replace('N/A', np.nan)
df['regents_exam'] = df['regents_exam'].replace('N/A', np.nan)
df['mean_score'] = df['mean_score'].replace('N/A', np.nan)
df['school_name'] = pd.to_numeric(df['school_name'], errors='coerce')
df['mean_score'] = pd.to_numeric(df['mean_score'], errors='coerce')
df['regents_exam'] = pd.to_numeric(df['regents_exam'], errors='coerce')
df[['school_name', 'mean_score', 'regents_exam']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   school_name   0 non-null       float64
#  1   mean_score    137109 non-null  float64
#  2   regents_exam  0 non-null       float64
# dtypes: float64(3)
# memory usage: 4.9 MB

# %% [markdown]
# ### Exercises – Section 6
# 1. Add another transformation to the column-name cleaning chain if needed.
# 2. Ensure `age` is numeric using `pd.to_numeric(df['age'], errors='coerce')`.
# 3. Create a new column `age_decade = df['age'] // 10`.

# %% [markdown]
# ## 7. Handling Missing Values
#
# We will impute missing numeric values with the **median**, which is robust to outliers.

# %%
# Check missing values again
df.isna().sum()
# Out:
# school_dbn                          0
# school_name                    212331
# school_level                        0
# regents_exam                   212331
# year                                0
# total_tested                        0
# mean_score                      75222
# number_scoring_below_65             0
# percent_scoring_below_65            0
# number_scoring_65_or_above          0
# percent_scoring_65_or_above         0
# number_scoring_80_or_above          0
# percent_scoring_80_or_above         0
# number_scoring_cr                   0
# percent_scoring_cr                  0
# dtype: int64

# %%
# Median imputation for school_name and mean_score
school_name_median = df['school_name'].median()
mean_score_median = df['mean_score'].median()
df['school_name'] = df['school_name'].fillna(school_name_median)
df['mean_score'] = df['mean_score'].fillna(mean_score_median)
df.isna().sum()
# Out:
# school_dbn                          0
# school_name                    212331
# school_level                        0
# regents_exam                   212331
# year                                0
# total_tested                        0
# mean_score                          0
# number_scoring_below_65             0
# percent_scoring_below_65            0
# number_scoring_65_or_above          0
# percent_scoring_65_or_above         0
# number_scoring_80_or_above          0
# percent_scoring_80_or_above         0
# number_scoring_cr                   0
# percent_scoring_cr                  0
# dtype: int64

# %% [markdown]
# ### Exercises – Section 7
# 1. Compare the number of missing `bmi` values before and after imputation.
# 2. Compute the mean and median of `bmi`. Why might we prefer the median?
# 3. For a categorical column like `smoking_status`, what imputation strategy would you use?

# %% [markdown]
# ## 8. Converting Columns to Categorical
#
# For columns that represent categories (e.g., gender, work type, hypertension), we convert them to the `category` dtype.

# %%
categorical_cols = [
    'school_name', 'mean_score','total_tested', 'regents_exam'
]

for col in categorical_cols:
    df[col] = df[col].astype('category')

df[categorical_cols].dtypes
# Out:
# school_name     category
# mean_score      category
# total_tested    category
# regents_exam    category
# dtype: object

# %% [markdown]
# ### Exercises – Section 8
# 1. View the categories for `gender` using `df['gender'].cat.categories`.
# 2. Check how imbalanced `stroke` is using `df['stroke'].value_counts(normalize=True)`.
# 3. Convert your `age_decade` column (from Section 6) to categorical.

# %% [markdown]
# ## 9. Descriptive Statistics – Numeric Columns

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
numeric_df.describe()
# Out:
#             year
# count 212,331.00
# mean    2,015.96
# std         0.80
# min     2,015.00
# 25%     2,015.00
# 50%     2,016.00
# 75%     2,017.00
# max     2,017.00

# %%
print('school_name summary:')
print(df['school_name'].describe())

print('\mean_score summary:')
print(df['mean_score'].describe())

print('\total_tested summary:')
print(df['total_tested'].describe())
# Out:
# school_name summary:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: school_name, dtype: object
# \mean_score summary:
# count    212,331.00
# unique       747.00
# top           65.40
# freq      75,747.00
# Name: mean_score, dtype: float64
# 	otal_tested summary:
# count     212331
# unique      1126
# top            1
# freq       22010
# Name: total_tested, dtype: int64
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-3145334504.py:4: SyntaxWarning: invalid escape sequence '\m'
#   print('\mean_score summary:')

# %% [markdown]
# ### Exercises – Section 9
# 1. Which numeric column has the largest standard deviation?
# 2. What are the minimum and maximum ages in the dataset?
# 3. Compute the IQR (Q3 - Q1) for `bmi`.

# %% [markdown]
# ## 10. Descriptive Statistics – Categorical Columns

# %%
def show_category_distribution(col_name):
    counts = df[col_name].value_counts()
    percents = df[col_name].value_counts(normalize=True) * 100
    display(pd.DataFrame({'count': counts, 'percent': percents.round(2)}))

for col in ['school_name', 'total_tested', 'mean_score']:
    print(f'--- {col} ---')
    show_category_distribution(col)
    print()
# Out:
# --- school_name ---
# Empty DataFrame
# Columns: [count, percent]
# Index: []
# --- total_tested ---
#               count  percent
# total_tested
# 1             22010    10.37
# 2             12750     6.00
# 3              9168     4.32
# 4              7264     3.42
# 5              6263     2.95
# ...             ...      ...
# 1554              1     0.00
# 1629              1     0.00
# 1648              1     0.00
# 1701              1     0.00
# 1729              1     0.00
#
# [1126 rows x 2 columns]
# --- mean_score ---
#             count  percent
# mean_score
# 65.40       75747    35.67
# 63.30         555     0.26
# 64.30         555     0.26
# 62.30         552     0.26
# 63.80         550     0.26
# ...           ...      ...
# 26.90           1     0.00
# 30.50           1     0.00
# 30.20           1     0.00
# 28.60           1     0.00
# 98.70           1     0.00
#
# [747 rows x 2 columns]

# %% [markdown]
# ### Exercises – Section 10
# 1. Which `work_type` appears most frequently?
# 2. What percentage of people fall into each `smoking_status` category?
# 3. Add `hypertension` to the loop and inspect its distribution.

# %% [markdown]
# ## 11. Univariate Visualizations – Numeric

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

sns.histplot(df['mean_score'], bins=10, kde=True, ax=axes[0])
axes[0].set_title('Mean Score Distribution')

sns.histplot(df['total_tested'], bins=50, kde=True, ax=axes[1])
axes[1].set_title('Total Tested Distribution')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4))

sns.boxplot(y=df['mean_score'], ax=axes[0])
axes[0].set_title('Mean Score Boxplot')

sns.boxplot(y=df['total_tested'], ax=axes[1])
axes[1].set_title('Total Tested Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercises – Section 11
# 1. Which numeric variable appears most skewed?
# 2. Which variable shows the most extreme outliers in the boxplots?
# 3. Create a single histogram of `age` with `bins=15` and add a title and axis labels.
